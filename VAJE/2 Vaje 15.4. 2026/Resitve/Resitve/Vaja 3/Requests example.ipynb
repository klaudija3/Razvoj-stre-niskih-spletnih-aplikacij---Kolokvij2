# %%
# curl -X 'PUT' 'http://127.0.0.1:1234/puttext' -H 'Content-Type: text/html'  -d 'ASD'

# curl -X 'PUT' 'http://127.0.0.1:1234/putjson' -H 'Content-Type: application/json' \
#   -d '{
#   "mytext":"Proba"
#   }'

# %%
import requests
import json

# %%
res = requests.get('http://127.0.0.1:1234/getall')

# %%
json.loads(res.text)
# Out:
# [{'ime': 'Martin', 'visina': '153'},
#  {'ime': 'Martin', 'visina': '153'},
#  {'ime': 'Martin', 'visina': '153'},
#  {'ime': 'Ziga', 'visina': '180'}]

# %%
res = requests.post('http://127.0.0.1:1234', json={'ime': 'Ziga', 'visina' : '180'})
print(res.text)
# Out:
# {
#   "ime": "Ziga",
#   "visina": "180"
# }

# %%
res = requests.put('http://127.0.0.1:1234', json={'ime': 'Martin', 'visina' : '153'})
print(res.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 res = requests.put('http://127.0.0.1:1234', json={'ime': 'Martin', 'visina' : '153'})
#       2 print(res.text)
#
# NameError: name 'requests' is not defined

# %%
res = requests.delete('http://149.62.71.186:1234', json={'ime': 'Martin'})
print(res.text)
# Out:
# {
#   "ime": "Martin"
# }
