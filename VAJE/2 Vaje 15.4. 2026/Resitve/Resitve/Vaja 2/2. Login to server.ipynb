# %%
from flask import Flask, redirect, url_for, request, render_template

app = Flask(__name__)

us_pass = {'martin' : 'martin00', 'student' : 'student00'}

@app.route('/success/<name>', methods = ['GET'])
def success(name):
    return 'Welcome, %s' % name

@app.route('/failure', methods = ['GET'])
def failure():
    return 'Wrong username or password'

@app.route('/login', methods = ['POST', 'GET'])
def login():
    if request.method == 'GET':
        return render_template('login.html')
    if request.method == 'POST':
        user = request.form['username']
        password = request.form['password']
        try:
            if us_pass[user] == password:
                return redirect(url_for('success',name = user))
            else:
                return redirect(url_for('failure',name = user))
        except:
            return redirect(url_for('failure',name = user))

# use_reloader da se ne refresha strn ku kej spremeniš
app.run(host='127.0.0.1',debug=True, port=1235, use_reloader=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:1235
# Press CTRL+C to quit
# 127.0.0.1 - - [09/May/2024 19:09:46] "POST /login HTTP/1.1" 302 -
# 127.0.0.1 - - [09/May/2024 19:09:46] "GET /failure?name=sdsf HTTP/1.1" 200 -
# 127.0.0.1 - - [09/May/2024 19:10:09] "POST /login HTTP/1.1" 302 -
# 127.0.0.1 - - [09/May/2024 19:10:09] "GET /success/martin HTTP/1.1" 200 -
# 127.0.0.1 - - [09/May/2024 19:10:38] "POST /login HTTP/1.1" 302 -
# 127.0.0.1 - - [09/May/2024 19:10:38] "GET /success/martin HTTP/1.1" 200 -
