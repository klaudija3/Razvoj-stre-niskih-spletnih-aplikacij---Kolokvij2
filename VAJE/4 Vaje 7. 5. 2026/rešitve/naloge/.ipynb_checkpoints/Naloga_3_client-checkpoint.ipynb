# %%
from Crypto.PublicKey import RSA
from Crypto.Random import get_random_bytes
from Crypto.Cipher import AES, PKCS1_OAEP
import socket
import select
import sys


def send_username():
    user = input("Username: ")
    data = user.encode('utf-8')

    cipher_aes = AES.new(session_key, AES.MODE_EAX)
    ciphertext, tag = cipher_aes.encrypt_and_digest(data)

    client_socket.sendall(cipher_aes.nonce)
    client_socket.sendall(tag)
    client_socket.sendall(ciphertext)
    print('Sent!')
    return user

def send_message():
    data = input(f'{user} > ')
    data = data.encode('utf-8')

    cipher_aes = AES.new(session_key, AES.MODE_EAX)
    ciphertext, tag = cipher_aes.encrypt_and_digest(data)

    client_socket.sendall(cipher_aes.nonce)
    client_socket.sendall(tag)
    client_socket.sendall(ciphertext)
    print('Sent!')


IP = "127.0.0.1"
PORT = 1234

recipient_key = RSA.import_key(open("receiver.pem").read())
session_key = get_random_bytes(16)

cipher_rsa = PKCS1_OAEP.new(recipient_key)
enc_session_key = cipher_rsa.encrypt(session_key)

client_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
client_socket.connect((IP, PORT))
client_socket.setblocking(False) #blokira server
client_socket.sendall(enc_session_key)

user = send_username()

while True: 
    send_message()
# Out:
# Username:  marko
# Sent!
# marko >  helo
# Sent!
# marko >  jah
# Sent!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 52
#      49 user = send_username()
#      51 while True:
# ---> 52     send_message()
#
# Cell In[5], line 23, in send_message()
#      22 def send_message():
# ---> 23     data = input(f'{user} > ')
#      24     data = data.encode('utf-8')
#      26     cipher_aes = AES.new(session_key, AES.MODE_EAX)
#
# File ~/miniconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py:1262, in Kernel.raw_input(self, prompt)
#    1260     msg = "raw_input was called, but this frontend does not support input requests."
#    1261     raise StdinNotImplementedError(msg)
# -> 1262 return self._input_request(
#    1263     str(prompt),
#    1264     self._parent_ident["shell"],
#    1265     self.get_parent("shell"),
#    1266     password=False,
#    1267 )
#
# File ~/miniconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py:1305, in Kernel._input_request(self, prompt, ident, parent, password)
#    1302 except KeyboardInterrupt:
#    1303     # re-raise KeyboardInterrupt, to truncate traceback
#    1304     msg = "Interrupted by user"
# -> 1305     raise KeyboardInterrupt(msg) from None
#    1306 except Exception:
#    1307     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
