# %%
import socket
import select
from Crypto.PublicKey import RSA
from Crypto.Random import get_random_bytes
from Crypto.Cipher import AES, PKCS1_OAEP

IP = "127.0.0.1"
PORT = 1232


private_key = RSA.import_key(open("private.pem").read())

server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
server_socket.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)
server_socket.bind((IP, PORT))
server_socket.listen()
sockets_list = [server_socket]
clients = {}
session_keys = {}
print(f'Listening for connections on {IP}:{PORT}...')

def receive_message(client_socket, session_key):
    nonce = client_socket.recv(16)
    tag = client_socket.recv(16)
    ciphertext = client_socket.recv(1000)

    cipher_aes = AES.new(session_key, AES.MODE_EAX, nonce)
    data = cipher_aes.decrypt_and_verify(ciphertext, tag)
    return data

def send_message(message, client_socket, session_key):
    cipher_aes = AES.new(session_key, AES.MODE_EAX)
    ciphertext, tag = cipher_aes.encrypt_and_digest(message)

    client_socket.sendall(cipher_aes.nonce)
    client_socket.sendall(tag)
    client_socket.sendall(ciphertext)

while True:
    read_sockets, _, _ = select.select(sockets_list, [], sockets_list) # Blokira, dokler nečesa ne sprejme
    for notified_socket in read_sockets:
        if notified_socket == server_socket:
            client_socket, client_address = server_socket.accept()
            
            # Najprej dobimo enc_session_key
            enc_session_key = client_socket.recv(private_key.size_in_bytes())

            # Ga dekriptiramo
            cipher_rsa = PKCS1_OAEP.new(private_key)
            session_key = cipher_rsa.decrypt(enc_session_key)
            
            # Ga shranimo v session_keys
            session_keys[client_socket] = session_key
            print('Session key is ', session_key)
            
            sockets_list.append(client_socket)
            user = receive_message(client_socket, session_keys[client_socket])
            if user is False:
                continue
            clients[client_socket] = user
            print('Sprejeta povezava od {}:{}, uporabniško ime: {}'.format(*client_address, user.decode('utf-8')))
        else:
            message = receive_message(notified_socket, session_keys[notified_socket])
            if message is False:
                print('Closed connection from: {}'.format(clients[notified_socket].decode('utf-8')))
                sockets_list.remove(notified_socket)
                del clients[notified_socket]
                continue
            user = clients[notified_socket]
            print(f'Prejeto sporočilo od {user.decode("utf-8")}: {message.decode("utf-8")}')
        
            for client_socket in clients:
                if client_socket != notified_socket:
                    full_message = user + ': '.encode() + message
                    print(full_message)
                    print(session_keys[client_socket])
                    send_message(full_message, client_socket, session_keys[client_socket])
# Out:
# Listening for connections on 127.0.0.1:1232...
# Session key is  b'\x87\xaf \r\x91C\xa8\x12MGC\xbe\x82\xf9\xdc\xe8'
# Sprejeta povezava od 127.0.0.1:57250, uporabniško ime: ziga1
# Prejeto sporočilo od ziga1: hallo
# Session key is  b'\x93\xbds\x95\x8f\xaa~\xea\xa5\xcd\x0eE\xacd\xd1\x08'
# Sprejeta povezava od 127.0.0.1:37786, uporabniško ime: ziga2
# Prejeto sporočilo od ziga2: hello
# b'ziga2: hello'
# b'\x87\xaf \r\x91C\xa8\x12MGC\xbe\x82\xf9\xdc\xe8'
# Prejeto sporočilo od ziga1: hello
# b'ziga1: hello'
# b'\x93\xbds\x95\x8f\xaa~\xea\xa5\xcd\x0eE\xacd\xd1\x08'
# Prejeto sporočilo od ziga2: d
# b'ziga2: d'
# b'\x87\xaf \r\x91C\xa8\x12MGC\xbe\x82\xf9\xdc\xe8'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 40
#      37     client_socket.sendall(ciphertext)
#      39 while True:
# ---> 40     read_sockets, _, _ = select.select(sockets_list, [], sockets_list) # Blokira, dokler nečesa ne sprejme
#      41     for notified_socket in read_sockets:
#      42         if notified_socket == server_socket:
#
# KeyboardInterrupt:
