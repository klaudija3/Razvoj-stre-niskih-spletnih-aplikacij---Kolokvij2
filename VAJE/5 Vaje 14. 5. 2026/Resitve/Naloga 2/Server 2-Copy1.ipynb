# %%
from concurrent import futures

import grpc

import ts_pb2 as ts
import ts_pb2_grpc as rpc


class Server(rpc.ServeServicer):

    def __init__(self):
        self.points = []

    def GetOne(self, request, context):
        i = request.index
        return self.points[i]
        
    def GetAll(self, request, context):
        for i in range(len(self.points)):
            yield self.points[i]

    def SendOne(self, request, context):
        print("value={}".format(request.value))
        self.points.append(request)
        return ts.Empty()


if __name__ == '__main__':
    port = 30011
    server = grpc.server(futures.ThreadPoolExecutor(max_workers=10))
    rpc.add_ServeServicer_to_server(Server(), server)
    # gRPC basically manages all the threading and server responding logic, which is perfect!
    print('Starting server. Listening...')
    server.add_insecure_port('[::]:' + str(port))
    server.start()
    server.wait_for_termination()
# Out:
# Starting server. Listening...
# value=1.2000000476837158
# value=1.2000000476837158
# value=1.2000000476837158
# value=2.200000047683716
# <grpc._server._Context object at 0x7fa7c21397c0>
# index: 1
#
# <class 'ts_pb2.PointIndex'>
# 1
# <grpc._server._Context object at 0x7fa7c2139520>
# index: 1
#
# <class 'ts_pb2.PointIndex'>
# 1
# <grpc._server._Context object at 0x7fa7c2139130>
# index: 1
#
# <class 'ts_pb2.PointIndex'>
# 1
# <grpc._server._Context object at 0x7fa7c2139670>
# index: 3
#
# <class 'ts_pb2.PointIndex'>
# 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-349c2dbe2dc8> in <module>
#      38     server.add_insecure_port('[::]:' + str(port))
#      39     server.start()
# ---> 40     server.wait_for_termination()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/grpc/_server.py in wait_for_termination(self, timeout)
#    1116         # Remove this workaround once threading.Event.wait() is working with
#    1117         # CTRL+C across platforms.
# -> 1118         return _common.wait(self._state.termination_event.wait,
#    1119                             self._state.termination_event.is_set,
#    1120                             timeout=timeout)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/grpc/_common.py in wait(wait_fn, wait_complete_fn, timeout, spin_cb)
#     148     if timeout is None:
#     149         while not wait_complete_fn():
# --> 150             _wait_once(wait_fn, MAXIMUM_WAIT_TIMEOUT, spin_cb)
#     151     else:
#     152         end = time.time() + timeout
#
# ~/opt/anaconda3/lib/python3.8/site-packages/grpc/_common.py in _wait_once(wait_fn, timeout, spin_cb)
#     110 def _wait_once(wait_fn: Callable[..., bool], timeout: float,
#     111                spin_cb: Optional[Callable[[], None]]):
# --> 112     wait_fn(timeout=timeout)
#     113     if spin_cb is not None:
#     114         spin_cb()
#
# ~/opt/anaconda3/lib/python3.8/threading.py in wait(self, timeout)
#     556             signaled = self._flag
#     557             if not signaled:
# --> 558                 signaled = self._cond.wait(timeout)
#     559             return signaled
#     560
#
# ~/opt/anaconda3/lib/python3.8/threading.py in wait(self, timeout)
#     304             else:
#     305                 if timeout > 0:
# --> 306                     gotit = waiter.acquire(True, timeout)
#     307                 else:
#     308                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
