# %%
import grpc
import test_pb2_grpc as pb2_grpc
import test_pb2 as pb2

channel = grpc.insecure_channel(f'127.0.0.1:10024')
stub = pb2_grpc.Naloga1Stub(channel)

# %%
asd = pb2.Sporocilo()

# %%
asd.text = 'Helloooo'

# %%
asd.text
# Out:
# 'Helloooo'

# %%
response = stub.VrniSporocilo(asd)
print(response)
# Out:
# text: "HELLOOOO"
