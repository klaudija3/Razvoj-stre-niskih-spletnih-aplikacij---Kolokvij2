# %%
import grpc
import test_pb2_grpc as pb2_grpc
import test_pb2 as pb2

channel = grpc.insecure_channel(f'127.0.0.1:10021')
stub = pb2_grpc.Naloga1Stub(channel)
message = pb2.Sporocilo(text='Helloooo')
response = stub.VrniSporocilo(message)
print(response)
# Out:
# text: "HELLOOOO"
