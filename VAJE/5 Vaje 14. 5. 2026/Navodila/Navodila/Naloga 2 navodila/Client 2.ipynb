# %%
import threading

import grpc

import ts_pb2 as ts
import ts_pb2_grpc as rpc

address = 'localhost'
port = 30000


class Client:

    def __init__(self):
        channel = grpc.insecure_channel(address + ':' + str(port))
        self.conn = rpc.ServeStub(channel)

    def put_point(self, value):
        # Definirajte objekt ts.Point z vrednostjo value ter ga pošljite s funkcijo SendOne

    def get_point(self, index):
        # Definirajte objekt ts.PointIndex, ga pošljite s funkcijo GetOne ter prejmite vrednost od strežnika
    
    def get_all_points(self):
        # Z GetAll pošljite Empty() ter prejmite vse točke od strežnika

    def iterator(self, point_objects):
        for point in point_objects:
            yield point
    def put_stream_point(self, values):
        # Za funkcijo SendMore morate poslati iterator objektov tipa ts.Point
        # Če želite, si lahko pomagate s funkcijo self.iterator(). Iz seznama objektov tipa ts.Point vam naredi iterator,
        # torej jo uporabite kot 
        #     self.conn.SendMore(self.iterator(point_objects))
        # kjer je point_objects seznam [ts.Point(value = ...), ts.Point(value = ...), ...]



c = Client()
c.put_point(1.2)
c.put_point(1.2)
c.put_point(2.2)
