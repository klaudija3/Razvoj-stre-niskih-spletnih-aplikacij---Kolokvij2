# %%
import grpc
import test_pb2_grpc as pb2_grpc
import test_pb2 as pb2

# Odpremo insecure_channel
# Naredimo Stub
# Definiramo pb2.Sporocilo
response = ...# Nazaj prejmemo odgovor

print(response)
