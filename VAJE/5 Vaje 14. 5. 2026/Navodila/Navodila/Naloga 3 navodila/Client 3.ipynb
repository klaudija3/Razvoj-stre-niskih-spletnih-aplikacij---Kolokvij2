# %%
import threading

import grpc

import chat_pb2 as chat
import chat_pb2_grpc as rpc

class Client:

    def __init__(self, username):
        # Shranimo username, odpremo connection in shranimo Stub
        
        threading.Thread(target=self.listen_for_messages, daemon=True).start() # S tem začnemo thread, s katerim sproti prejemamo sporočila

    def listen_for_messages(self):
        for note in ...:#
            print(...)
    def send_message(self):
        message = input(f'[{self.username}]: ')
        # Naredimo Note in ga pošljemo s SendNote


username = input('Username: ')
c = Client(username)
# Pošiljamo sporočila - kako?
# Out:
# <>:20: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:20: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-00496dcbeaac> in <module>
#       3 import grpc
#       4
# ----> 5 import chat_pb2 as chat
#       6 import chat_pb2_grpc as rpc
#       7
#
# ModuleNotFoundError: No module named 'chat_pb2'
