# %%
from concurrent import futures

import grpc
import time

import chat_pb2 as chat
import chat_pb2_grpc as rpc


class ChatServer(rpc.ChatServerServicer):

    def __init__(self):
        self.chats = [] # To je na začetku prazen seznam, v katerega shranjujemo nova sporočila in jih pošiljamo uporabnikom

    def ChatStream(self, request_iterator, context):
        while ...
            sporocilo = ...
            yield sporocilo

    def SendNote(self, request: chat.Note, context):
        print("[{}] {}".format(request.name, request.message))
        # v self.chats dodamo novi message, in vrnemo prazen message


server = ...
# dodamo Servicer
# dodamo insecure_port
# start server
# wait for termination
# Out:
# Starting server. Listening...
